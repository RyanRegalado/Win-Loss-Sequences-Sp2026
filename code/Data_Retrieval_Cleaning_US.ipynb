# %%
import pandas as pd
from sportsipy.nba.schedule import Schedule as NBASchedule
from sportsipy.mlb.schedule import Schedule as MLBSchedule
from sportsipy.constants import WIN, LOSS

# %%
"""
Quick Sportsipy API Test
=========================
Run this to quickly verify if sportsipy is working.
"""

print("Testing sportsipy API...\n")

# Test 1: Simple NBA Schedule Test
print("="*60)
print("Test 1: NBA Schedule (Lakers 2023)")
print("="*60)

try:
    from sportsipy.nba.schedule import Schedule
    
    schedule = Schedule('LAL', year='2023')
    print(f"✅ SUCCESS: Retrieved {len(schedule)} games")
    print(f"   First game: {schedule[0].date} vs {schedule[0].opponent_abbr}")
    print(f"   Result: {schedule[0].result}")
    
except Exception as e:
    print(f"❌ FAILED: {e}")

# Test 2: NBA Teams
print("\n" + "="*60)
print("Test 2: NBA Teams (2023 season)")
print("="*60)

try:
    from sportsipy.nba.teams import Teams
    
    teams = Teams(year='2023')
    print(f"✅ SUCCESS: Retrieved {len(teams)} teams")
    
    # Show top 3 teams by wins
    teams_list = list(teams)
    teams_sorted = sorted(teams_list, key=lambda t: t.wins, reverse=True)[:3]
    print("   Top 3 teams by wins:")
    for team in teams_sorted:
        print(f"     • {team.name}: {team.wins}-{team.losses}")
    
except Exception as e:
    print(f"❌ FAILED: {e}")

# Test 3: MLB Schedule
print("\n" + "="*60)
print("Test 3: MLB Schedule (Yankees 2023)")
print("="*60)

try:
    from sportsipy.mlb.schedule import Schedule
    
    schedule = Schedule('NYY', year='2023')
    print(f"✅ SUCCESS: Retrieved {len(schedule)} games")
    print(f"   First game: {schedule[0].date} vs {schedule[0].opponent_abbr}")
    
except Exception as e:
    print(f"❌ FAILED: {e}")

# Test 4: Win/Loss Sequence (Your main use case)
print("\n" + "="*60)
print("Test 4: Win/Loss Sequence Extraction")
print("="*60)

try:
    from sportsipy.nba.schedule import Schedule
    from sportsipy.constants import WIN, LOSS
    
    schedule = Schedule('LAL', year='2023')
    
    # Extract sequence
    sequence = ''.join(['W' if game.result == WIN else 'L' for game in schedule])
    wins = sequence.count('W')
    losses = sequence.count('L')
    
    print(f"✅ SUCCESS: Extracted sequence")
    print(f"   Record: {wins}-{losses}")
    print(f"   Sequence (first 40): {sequence[:40]}...")
    print(f"   Full length: {len(sequence)} games")
    
except Exception as e:
    print(f"❌ FAILED: {e}")

# Test 5: Different seasons
print("\n" + "="*60)
print("Test 5: Testing Different Seasons")
print("="*60)

seasons_to_test = ['2023', '2022', '2021', '2020']

try:
    from sportsipy.nba.schedule import Schedule
    
    for season in seasons_to_test:
        try:
            schedule = Schedule('LAL', year=season)
            print(f"   {season}: ✅ {len(schedule)} games")
        except Exception as e:
            print(f"   {season}: ❌ {str(e)[:40]}...")
    
except Exception as e:
    print(f"❌ FAILED: {e}")

print("\n" + "="*60)
print("DONE - Check results above")
print("="*60)
# Out:
# Testing sportsipy API...
#
# ============================================================
# Test 1: NBA Schedule (Lakers 2023)
# ============================================================
# The requested page returned a valid response, but no data could be found. Has the season begun, and is the data available on www.sports-reference.com?
# ✅ SUCCESS: Retrieved 0 games
# ❌ FAILED: list index out of range
#
# ============================================================
# Test 2: NBA Teams (2023 season)
# ============================================================
# The requested page returned a valid response, but no data could be found. Has the season begun, and is the data available on www.sports-reference.com?
# ✅ SUCCESS: Retrieved 0 teams
#    Top 3 teams by wins:
#
# ============================================================
# Test 3: MLB Schedule (Yankees 2023)
# ============================================================
# The requested page returned a valid response, but no data could be found. Has the season begun, and is the data available on www.sports-reference.com?
# ✅ SUCCESS: Retrieved 0 games
# ❌ FAILED: list index out of range
#
# ============================================================
# Test 4: Win/Loss Sequence Extraction
# ============================================================
# The requested page returned a valid response, but no data could be found. Has the season begun, and is the data available on www.sports-reference.com?
# ✅ SUCCESS: Extracted sequence
#    Record: 0-0
#    Sequence (first 40): ...
#    Full length: 0 games
#
# ============================================================
# Test 5: Testing Different Seasons
# ============================================================
# The requested page returned a valid response, but no data could be found. Has the season begun, and is the data available on www.sports-reference.com?
#    2023: ✅ 0 games
# The requested page returned a valid response, but no data could be found. Has the season begun, and is the data available on www.sports-reference.com?
#    2022: ✅ 0 games
# The requested page returned a valid response, but no data could be found. Has the season begun, and is the data available on www.sports-reference.com?
#    2021: ✅ 0 games
# The requested page returned a valid response, but no data could be found. Has the season begun, and is the data available on www.sports-reference.com?
#    2020: ✅ 0 games
#
# ============================================================
# DONE - Check results above
# ============================================================

# %%
## nba_api try

## Notes it only works from 1983 on.

from nba_api.stats.endpoints import leaguegamefinder
import pandas as pd

# %%
from nba_api.stats.endpoints import leaguegamefinder
import pandas as pd
import time

def get_all_nba_schedules(start_year=1983, end_year=2025):
    """
    Get all NBA regular season schedules from start_year to end_year.
    
    Parameters:
    - start_year: First year to fetch (default: 1983)
    - end_year: Last year to fetch (default: 2025)
    
    Returns:
    - DataFrame with all games
    """
    all_games = []
    
    for year in range(start_year, end_year):
        # NBA seasons are formatted as 'YYYY-YY' (e.g., '1983-84')
        season = f"{year}-{str(year + 1)[-2:]}"
        
        print(f"Fetching season {season}...")
        
        try:
            # Get games for this season
            gamefinder = leaguegamefinder.LeagueGameFinder(
                season_nullable=season,
                league_id_nullable='00',  # '00' = NBA
                season_type_nullable='Regular Season'
            )
            
            games = gamefinder.get_data_frames()[0]
            all_games.append(games)
            
            print(f"  Found {len(games)} game records for {season}")
            
            # Be respectful to the API - add a small delay
            time.sleep(0.6)
            
        except Exception as e:
            print(f"  Error fetching {season}: {e}")
            continue
    
    # Combine all seasons into one DataFrame
    if all_games:
        full_schedule = pd.concat(all_games, ignore_index=True)
        print(f"\nTotal game records: {len(full_schedule)}")
        return full_schedule
    else:
        print("No games found")
        return pd.DataFrame()

# %%
schedules = get_all_nba_schedules(1983, 2025)
# Out:
# Fetching season 1983-84...
#   Found 1886 game records for 1983-84
# Fetching season 1984-85...
#   Found 1886 game records for 1984-85
# Fetching season 1985-86...
#   Found 1886 game records for 1985-86
# Fetching season 1986-87...
#   Found 1886 game records for 1986-87
# Fetching season 1987-88...
#   Found 1886 game records for 1987-88
# Fetching season 1988-89...
#   Found 2050 game records for 1988-89
# Fetching season 1989-90...
#   Found 2214 game records for 1989-90
# Fetching season 1990-91...
#   Found 2214 game records for 1990-91
# Fetching season 1991-92...
#   Found 2214 game records for 1991-92
# Fetching season 1992-93...
#   Found 2214 game records for 1992-93
# Fetching season 1993-94...
#   Found 2214 game records for 1993-94
# Fetching season 1994-95...
#   Found 2214 game records for 1994-95
# Fetching season 1995-96...
#   Found 2378 game records for 1995-96
# Fetching season 1996-97...
#   Found 2378 game records for 1996-97
# Fetching season 1997-98...
#   Found 2378 game records for 1997-98
# Fetching season 1998-99...
#   Found 1450 game records for 1998-99
# Fetching season 1999-00...
#   Found 2378 game records for 1999-00
# Fetching season 2000-01...
#   Found 2378 game records for 2000-01
# Fetching season 2001-02...
#   Found 2378 game records for 2001-02
# Fetching season 2002-03...
#   Found 2378 game records for 2002-03
# Fetching season 2003-04...
#   Found 2378 game records for 2003-04
# Fetching season 2004-05...
#   Found 2460 game records for 2004-05
# Fetching season 2005-06...
#   Found 2460 game records for 2005-06
# Fetching season 2006-07...
#   Found 2460 game records for 2006-07
# Fetching season 2007-08...
#   Found 2460 game records for 2007-08
# Fetching season 2008-09...
#   Found 2460 game records for 2008-09
# Fetching season 2009-10...
#   Found 2460 game records for 2009-10
# Fetching season 2010-11...
#   Found 2460 game records for 2010-11
# Fetching season 2011-12...
#   Found 1980 game records for 2011-12
# Fetching season 2012-13...
#   Found 2458 game records for 2012-13
# Fetching season 2013-14...
#   Found 2460 game records for 2013-14
# Fetching season 2014-15...
#   Found 2460 game records for 2014-15
# Fetching season 2015-16...
#   Found 2460 game records for 2015-16
# Fetching season 2016-17...
#   Found 2460 game records for 2016-17
# Fetching season 2017-18...
#   Found 2460 game records for 2017-18
# Fetching season 2018-19...
#   Found 2460 game records for 2018-19
# Fetching season 2019-20...
#   Found 2118 game records for 2019-20
# Fetching season 2020-21...
#   Found 2160 game records for 2020-21
# Fetching season 2021-22...
#   Found 2460 game records for 2021-22
# Fetching season 2022-23...
#   Found 2460 game records for 2022-23
# Fetching season 2023-24...
#   Found 2460 game records for 2023-24
# Fetching season 2024-25...
#   Found 2460 game records for 2024-25
#
# Total game records: 95774
# C:\Users\ryanj\AppData\Local\Temp\ipykernel_34412\2578252527.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   full_schedule = pd.concat(all_games, ignore_index=True)

# %%
schedules
# Out:
#       SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0         21983  1610612744               GOS   Golden State Warriors
# 1         21983  1610612747               LAL      Los Angeles Lakers
# 2         21983  1610612742               DAL        Dallas Mavericks
# 3         21983  1610612757               POR  Portland Trail Blazers
# 4         21983  1610612738               BOS          Boston Celtics
# ...         ...         ...               ...                     ...
# 95769     22024  1610612737               ATL           Atlanta Hawks
# 95770     22024  1610612752               NYK         New York Knicks
# 95771     22024  1610612738               BOS          Boston Celtics
# 95772     22024  1610612750               MIN  Minnesota Timberwolves
# 95773     22024  1610612747               LAL      Los Angeles Lakers
#
#           GAME_ID   GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  \
# 0      0028300938  1984-04-15  GOS vs. DAL  W  240   98  ...   0.571  21.0
# 1      0028300942  1984-04-15  LAL vs. PHX  L  240  114  ...   0.867  13.0
# 2      0028300938  1984-04-15    DAL @ GOS  L  240   96  ...   0.625  19.0
# 3      0028300940  1984-04-15    POR @ SEA  L  240  103  ...   0.806   7.0
# 4      0028300941  1984-04-15  BOS vs. NJN  W  240  118  ...   0.840  13.0
# ...           ...         ...          ... ..  ...  ...  ...     ...   ...
# 95769  0022400064  2024-10-23  ATL vs. BKN  W  241  120  ...   0.717  12.0
# 95770  0022400061  2024-10-22    NYK @ BOS  L  241  109  ...   0.750   5.0
# 95771  0022400061  2024-10-22  BOS vs. NYK  W  240  132  ...   0.875  11.0
# 95772  0022400062  2024-10-22    MIN @ LAL  L  239  103  ...   0.741  12.0
# 95773  0022400062  2024-10-22  LAL vs. MIN  W  240  110  ...   0.840  15.0
#
#        DREB   REB  AST   STL  BLK  TOV  PF  PLUS_MINUS
# 0      29.0  50.0   20  14.0    4   24  19         NaN
# 1      29.0  42.0   24  11.0    5   22  26         NaN
# 2      24.0  43.0   17   8.0    0   24  18         NaN
# 3      30.0  37.0   24   8.0    3   18  28         NaN
# 4      37.0  50.0   31   8.0    6   17  17         NaN
# ...     ...   ...  ...   ...  ...  ...  ..         ...
# 95769  33.0  45.0   25  12.0    9   16  20         4.0
# 95770  29.0  34.0   20   2.0    3   11  12       -23.0
# 95771  29.0  40.0   33   6.0    3    3  15        23.0
# 95772  35.0  47.0   17   4.0    1   15  22        -7.0
# 95773  31.0  46.0   22   7.0    8    7  22         7.0
#
# [95774 rows x 28 columns]
