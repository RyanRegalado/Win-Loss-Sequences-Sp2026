# %%
import pandas as pd
from scipy.special import comb
from scipy.stats import ttest_ind
from statsmodels.stats.proportion import proportions_ztest
import ast
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
soccer_ternary = pd.read_csv('../../data/processed/soccer.csv', index_col=0)
soccer_ternary
# Out:
#           League  Season           Team  \
# 0     Bundesliga    2000  Bayern Munich
# 1     Bundesliga    2000         Bochum
# 2     Bundesliga    2000        Cottbus
# 3     Bundesliga    2000       Dortmund
# 4     Bundesliga    2000  Ein Frankfurt
# ...          ...     ...            ...
# 1433     La_Liga    2024       Sociedad
# 1434     La_Liga    2024       Valencia
# 1435     La_Liga    2024     Valladolid
# 1436     La_Liga    2024      Vallecano
# 1437     La_Liga    2024     Villarreal
#
#                                                Sequence
# 0     [3, 3, 3, 0, 3, 3, 0, 0, 3, 1, 3, 0, 0, 1, 3, ...
# 1     [3, 0, 0, 0, 3, 1, 3, 0, 0, 0, 1, 0, 1, 0, 3, ...
# 2     [0, 0, 0, 3, 0, 0, 1, 3, 0, 3, 1, 3, 0, 0, 3, ...
# 3     [3, 3, 0, 3, 3, 0, 1, 3, 0, 0, 0, 3, 1, 3, 3, ...
# 4     [3, 0, 3, 0, 3, 1, 1, 0, 0, 3, 0, 3, 3, 0, 0, ...
# ...                                                 ...
# 1433  [0, 3, 0, 1, 0, 0, 1, 3, 1, 3, 0, 3, 3, 0, 3, ...
# 1434  [0, 0, 0, 1, 0, 3, 1, 0, 1, 0, 1, 3, 0, 0, 0, ...
# 1435  [3, 0, 1, 0, 0, 1, 0, 0, 0, 3, 0, 0, 1, 0, 0, ...
# 1436  [3, 1, 0, 0, 3, 1, 1, 1, 3, 0, 3, 0, 0, 0, 3, ...
# 1437  [1, 3, 3, 1, 3, 0, 3, 3, 0, 1, 3, 3, 1, 1, 0, ...
#
# [1438 rows x 4 columns]

# %%
# Out:
# Requirement already satisfied: statsmodels in C:\Users\jjgoe\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in C:\Users\jjgoe\AppData\Local\Programs\Python\Python314\Lib\site-packages (from statsmodels) (2.4.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in C:\Users\jjgoe\AppData\Local\Programs\Python\Python314\Lib\site-packages (from statsmodels) (1.17.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in C:\Users\jjgoe\AppData\Local\Programs\Python\Python314\Lib\site-packages (from statsmodels) (3.0.0)
# Requirement already satisfied: patsy>=0.5.6 in C:\Users\jjgoe\AppData\Local\Programs\Python\Python314\Lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in C:\Users\jjgoe\AppData\Local\Programs\Python\Python314\Lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\jjgoe\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\jjgoe\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in C:\Users\jjgoe\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
def prob(sequence):
    return sum(sequence) / len(sequence)

def split(sequence):

    n1 = math.ceil(len(sequence) / 2)

    s1 = sequence[:n1] # includes the first n1 elements
    s2 = sequence[n1:] # the rest of the elements

    return s1,s2

# %%
def c2(sequence):
    s1, s2 = split(sequence)

    k1 = sum(s1)
    k2 = sum(s2)

    n1 = len(s1)*3
    n2 = len(s2)*3

    _, p = proportions_ztest([k1, k2], [n1, n2], alternative = "larger")

    if (p == 0):
        return math.inf
    else:
        return 1 / p

# %%
soccer_ternary['Sequence_Numeric'] = soccer_ternary['Sequence'].apply(ast.literal_eval)

# %%
## Add Columns n, n1, n2, k, k1, k2

soccer_ternary['n'] = soccer_ternary['Sequence_Numeric'].apply(len)

splits = soccer_ternary['Sequence_Numeric'].apply(split)

soccer_ternary['n1'] = splits.apply(lambda x: len(x[0]))
soccer_ternary['n2'] = splits.apply(lambda x: len(x[1]))

soccer_ternary['k'] = soccer_ternary['Sequence_Numeric'].apply(sum)
soccer_ternary['k1'] = splits.apply(lambda x: sum(x[0]))
soccer_ternary['k2'] = splits.apply(lambda x: sum(x[1]))
# Apply C1

#soccer_ternary['c1'] = [c1(seq) for seq in soccer_ternary['Sequence_Numeric']]
# Apply C2

soccer_ternary['c2'] = [c2(seq) for seq in soccer_ternary['Sequence_Numeric']]
# Out:
# C:\Users\jjgoe\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\stats\weightstats.py:792: RuntimeWarning: invalid value encountered in scalar divide
#   zstat = value / std

# %%
soccer_ternary
# Out:
#           League  Season           Team  \
# 0     Bundesliga    2000  Bayern Munich
# 1     Bundesliga    2000         Bochum
# 2     Bundesliga    2000        Cottbus
# 3     Bundesliga    2000       Dortmund
# 4     Bundesliga    2000  Ein Frankfurt
# ...          ...     ...            ...
# 1433     La_Liga    2024       Sociedad
# 1434     La_Liga    2024       Valencia
# 1435     La_Liga    2024     Valladolid
# 1436     La_Liga    2024      Vallecano
# 1437     La_Liga    2024     Villarreal
#
#                                                Sequence  \
# 0     [3, 3, 3, 0, 3, 3, 0, 0, 3, 1, 3, 0, 0, 1, 3, ...
# 1     [3, 0, 0, 0, 3, 1, 3, 0, 0, 0, 1, 0, 1, 0, 3, ...
# 2     [0, 0, 0, 3, 0, 0, 1, 3, 0, 3, 1, 3, 0, 0, 3, ...
# 3     [3, 3, 0, 3, 3, 0, 1, 3, 0, 0, 0, 3, 1, 3, 3, ...
# 4     [3, 0, 3, 0, 3, 1, 1, 0, 0, 3, 0, 3, 3, 0, 0, ...
# ...                                                 ...
# 1433  [0, 3, 0, 1, 0, 0, 1, 3, 1, 3, 0, 3, 3, 0, 3, ...
# 1434  [0, 0, 0, 1, 0, 3, 1, 0, 1, 0, 1, 3, 0, 0, 0, ...
# 1435  [3, 0, 1, 0, 0, 1, 0, 0, 0, 3, 0, 0, 1, 0, 0, ...
# 1436  [3, 1, 0, 0, 3, 1, 1, 1, 3, 0, 3, 0, 0, 0, 3, ...
# 1437  [1, 3, 3, 1, 3, 0, 3, 3, 0, 1, 3, 3, 1, 1, 0, ...
#
#                                        Sequence_Numeric   n  n1  n2   k  k1  \
# 0     [3, 3, 3, 0, 3, 3, 0, 0, 3, 1, 3, 0, 0, 1, 3, ...  34  17  17  63  30
# 1     [3, 0, 0, 0, 3, 1, 3, 0, 0, 0, 1, 0, 1, 0, 3, ...  34  17  17  27  18
# 2     [0, 0, 0, 3, 0, 0, 1, 3, 0, 3, 1, 3, 0, 0, 3, ...  34  17  17  39  17
# 3     [3, 3, 0, 3, 3, 0, 1, 3, 0, 0, 0, 3, 1, 3, 3, ...  34  17  17  58  30
# 4     [3, 0, 3, 0, 3, 1, 1, 0, 0, 3, 0, 3, 3, 0, 0, ...  34  17  17  35  20
# ...                                                 ...  ..  ..  ..  ..  ..
# 1433  [0, 3, 0, 1, 0, 0, 1, 3, 1, 3, 0, 3, 3, 0, 3, ...  38  19  19  46  28
# 1434  [0, 0, 0, 1, 0, 3, 1, 0, 1, 0, 1, 3, 0, 0, 0, ...  38  19  19  46  13
# 1435  [3, 0, 1, 0, 0, 1, 0, 0, 0, 3, 0, 0, 1, 0, 0, ...  38  19  19  16  15
# 1436  [3, 1, 0, 0, 3, 1, 1, 1, 3, 0, 3, 0, 0, 0, 3, ...  38  19  19  52  25
# 1437  [1, 3, 3, 1, 3, 0, 3, 3, 0, 1, 3, 3, 1, 1, 0, ...  38  19  19  70  30
#
#       k2            c2
# 0     33      1.370834
# 1      9     46.089683
# 2     22      1.182258
# 3     28      2.901612
# 4     15      6.733019
# ...   ..           ...
# 1433  18     35.552617
# 1434  33      1.000067
# 1435   1  12495.251146
# 1436  27      1.546616
# 1437  40      1.027945
#
# [1438 rows x 12 columns]

# %%
soccer_ternary['Team_Name'] = soccer_ternary['Season'].astype(str) + ' ' + soccer_ternary['Team']
soccer_ternary
# Out:
#           League  Season           Team  \
# 0     Bundesliga    2000  Bayern Munich
# 1     Bundesliga    2000         Bochum
# 2     Bundesliga    2000        Cottbus
# 3     Bundesliga    2000       Dortmund
# 4     Bundesliga    2000  Ein Frankfurt
# ...          ...     ...            ...
# 1433     La_Liga    2024       Sociedad
# 1434     La_Liga    2024       Valencia
# 1435     La_Liga    2024     Valladolid
# 1436     La_Liga    2024      Vallecano
# 1437     La_Liga    2024     Villarreal
#
#                                                Sequence  \
# 0     [3, 3, 3, 0, 3, 3, 0, 0, 3, 1, 3, 0, 0, 1, 3, ...
# 1     [3, 0, 0, 0, 3, 1, 3, 0, 0, 0, 1, 0, 1, 0, 3, ...
# 2     [0, 0, 0, 3, 0, 0, 1, 3, 0, 3, 1, 3, 0, 0, 3, ...
# 3     [3, 3, 0, 3, 3, 0, 1, 3, 0, 0, 0, 3, 1, 3, 3, ...
# 4     [3, 0, 3, 0, 3, 1, 1, 0, 0, 3, 0, 3, 3, 0, 0, ...
# ...                                                 ...
# 1433  [0, 3, 0, 1, 0, 0, 1, 3, 1, 3, 0, 3, 3, 0, 3, ...
# 1434  [0, 0, 0, 1, 0, 3, 1, 0, 1, 0, 1, 3, 0, 0, 0, ...
# 1435  [3, 0, 1, 0, 0, 1, 0, 0, 0, 3, 0, 0, 1, 0, 0, ...
# 1436  [3, 1, 0, 0, 3, 1, 1, 1, 3, 0, 3, 0, 0, 0, 3, ...
# 1437  [1, 3, 3, 1, 3, 0, 3, 3, 0, 1, 3, 3, 1, 1, 0, ...
#
#                                        Sequence_Numeric   n  n1  n2   k  k1  \
# 0     [3, 3, 3, 0, 3, 3, 0, 0, 3, 1, 3, 0, 0, 1, 3, ...  34  17  17  63  30
# 1     [3, 0, 0, 0, 3, 1, 3, 0, 0, 0, 1, 0, 1, 0, 3, ...  34  17  17  27  18
# 2     [0, 0, 0, 3, 0, 0, 1, 3, 0, 3, 1, 3, 0, 0, 3, ...  34  17  17  39  17
# 3     [3, 3, 0, 3, 3, 0, 1, 3, 0, 0, 0, 3, 1, 3, 3, ...  34  17  17  58  30
# 4     [3, 0, 3, 0, 3, 1, 1, 0, 0, 3, 0, 3, 3, 0, 0, ...  34  17  17  35  20
# ...                                                 ...  ..  ..  ..  ..  ..
# 1433  [0, 3, 0, 1, 0, 0, 1, 3, 1, 3, 0, 3, 3, 0, 3, ...  38  19  19  46  28
# 1434  [0, 0, 0, 1, 0, 3, 1, 0, 1, 0, 1, 3, 0, 0, 0, ...  38  19  19  46  13
# 1435  [3, 0, 1, 0, 0, 1, 0, 0, 0, 3, 0, 0, 1, 0, 0, ...  38  19  19  16  15
# 1436  [3, 1, 0, 0, 3, 1, 1, 1, 3, 0, 3, 0, 0, 0, 3, ...  38  19  19  52  25
# 1437  [1, 3, 3, 1, 3, 0, 3, 3, 0, 1, 3, 3, 1, 1, 0, ...  38  19  19  70  30
#
#       k2            c2           Team_Name
# 0     33      1.370834  2000 Bayern Munich
# 1      9     46.089683         2000 Bochum
# 2     22      1.182258        2000 Cottbus
# 3     28      2.901612       2000 Dortmund
# 4     15      6.733019  2000 Ein Frankfurt
# ...   ..           ...                 ...
# 1433  18     35.552617       2024 Sociedad
# 1434  33      1.000067       2024 Valencia
# 1435   1  12495.251146     2024 Valladolid
# 1436  27      1.546616      2024 Vallecano
# 1437  40      1.027945     2024 Villarreal
#
# [1438 rows x 13 columns]

# %%
#c3
def c3(sequence, N):

    sequence = np.asarray(sequence)   # convert once
    M = 0

    _, s2 = split(sequence)
    k2 = np.sum(s2)

    for _ in range(N):
        shuffled = np.random.permutation(sequence)  # new shuffled copy
        _, tmp = split(shuffled)

        if np.sum(tmp) <= k2:
            M += 1

    return N / M if M != 0 else math.inf

# %%
N = 1000
soccer_ternary['c3'] = [c3(seq, N) for seq in soccer_ternary['Sequence_Numeric']]

# %%
## Recalculate top 100 in c3 column 

soccer_indexes = list(soccer_ternary.sort_values('c3', ascending = False).head(100).index)

N = 100000


mask = soccer_ternary.index.isin(soccer_indexes)
soccer_ternary.loc[mask, 'c3'] = soccer_ternary.loc[mask, 'Sequence_Numeric'].apply(lambda seq: c3(seq, N))

# %%
soccer_ternary
# Out:
#           League  Season           Team  \
# 0     Bundesliga    2000  Bayern Munich
# 1     Bundesliga    2000         Bochum
# 2     Bundesliga    2000        Cottbus
# 3     Bundesliga    2000       Dortmund
# 4     Bundesliga    2000  Ein Frankfurt
# ...          ...     ...            ...
# 1433     La_Liga    2024       Sociedad
# 1434     La_Liga    2024       Valencia
# 1435     La_Liga    2024     Valladolid
# 1436     La_Liga    2024      Vallecano
# 1437     La_Liga    2024     Villarreal
#
#                                                Sequence  \
# 0     [3, 3, 3, 0, 3, 3, 0, 0, 3, 1, 3, 0, 0, 1, 3, ...
# 1     [3, 0, 0, 0, 3, 1, 3, 0, 0, 0, 1, 0, 1, 0, 3, ...
# 2     [0, 0, 0, 3, 0, 0, 1, 3, 0, 3, 1, 3, 0, 0, 3, ...
# 3     [3, 3, 0, 3, 3, 0, 1, 3, 0, 0, 0, 3, 1, 3, 3, ...
# 4     [3, 0, 3, 0, 3, 1, 1, 0, 0, 3, 0, 3, 3, 0, 0, ...
# ...                                                 ...
# 1433  [0, 3, 0, 1, 0, 0, 1, 3, 1, 3, 0, 3, 3, 0, 3, ...
# 1434  [0, 0, 0, 1, 0, 3, 1, 0, 1, 0, 1, 3, 0, 0, 0, ...
# 1435  [3, 0, 1, 0, 0, 1, 0, 0, 0, 3, 0, 0, 1, 0, 0, ...
# 1436  [3, 1, 0, 0, 3, 1, 1, 1, 3, 0, 3, 0, 0, 0, 3, ...
# 1437  [1, 3, 3, 1, 3, 0, 3, 3, 0, 1, 3, 3, 1, 1, 0, ...
#
#                                        Sequence_Numeric   n  n1  n2   k  k1  \
# 0     [3, 3, 3, 0, 3, 3, 0, 0, 3, 1, 3, 0, 0, 1, 3, ...  34  17  17  63  30
# 1     [3, 0, 0, 0, 3, 1, 3, 0, 0, 0, 1, 0, 1, 0, 3, ...  34  17  17  27  18
# 2     [0, 0, 0, 3, 0, 0, 1, 3, 0, 3, 1, 3, 0, 0, 3, ...  34  17  17  39  17
# 3     [3, 3, 0, 3, 3, 0, 1, 3, 0, 0, 0, 3, 1, 3, 3, ...  34  17  17  58  30
# 4     [3, 0, 3, 0, 3, 1, 1, 0, 0, 3, 0, 3, 3, 0, 0, ...  34  17  17  35  20
# ...                                                 ...  ..  ..  ..  ..  ..
# 1433  [0, 3, 0, 1, 0, 0, 1, 3, 1, 3, 0, 3, 3, 0, 3, ...  38  19  19  46  28
# 1434  [0, 0, 0, 1, 0, 3, 1, 0, 1, 0, 1, 3, 0, 0, 0, ...  38  19  19  46  13
# 1435  [3, 0, 1, 0, 0, 1, 0, 0, 0, 3, 0, 0, 1, 0, 0, ...  38  19  19  16  15
# 1436  [3, 1, 0, 0, 3, 1, 1, 1, 3, 0, 3, 0, 0, 0, 3, ...  38  19  19  52  25
# 1437  [1, 3, 3, 1, 3, 0, 3, 3, 0, 1, 3, 3, 1, 1, 0, ...  38  19  19  70  30
#
#       k2            c2           Team_Name         c3
# 0     33      1.370834  2000 Bayern Munich   1.379310
# 1      9     46.089683         2000 Bochum   7.246377
# 2     22      1.182258        2000 Cottbus   1.283697
# 3     28      2.901612       2000 Dortmund   2.309469
# 4     15      6.733019  2000 Ein Frankfurt   3.333333
# ...   ..           ...                 ...        ...
# 1433  18     35.552617       2024 Sociedad   7.633588
# 1434  33      1.000067       2024 Valencia   1.001001
# 1435   1  12495.251146     2024 Valladolid  91.074681
# 1436  27      1.546616      2024 Vallecano   1.524390
# 1437  40      1.027945     2024 Villarreal   1.092896
#
# [1438 rows x 14 columns]

# %%
soccer_ternary_output = "../../output/csvs/soccer_ternary_output.csv"

# %%
soccer_ternary_out = soccer_ternary[['League', 'Season', 'Team', 'Sequence', 'n', 'n1', 'n2', 'k', 'k1', 'k2', 'Team_Name', 'c2', 'c3']]

# %%
soccer_ternary_out.to_csv(soccer_ternary_output)
