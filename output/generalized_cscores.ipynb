# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
us = pd.read_csv("csvs/us_generalized_cscores.csv")
soccer = pd.read_csv("csvs/soccer_generalized_cscores.csv")

# %%
us['log_c1*'] = np.log(us['c1*'])
soccer['log_c1*'] = np.log(soccer['c1*'])

us['log_c2*'] = np.log(us['c2*'])
soccer['log_c2*'] = np.log(soccer['c2*'])
# Out:
# C:\Users\ryanj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
us["name"] = us["Season"].astype(str) + " " + us["Team"]
soccer["name"] = soccer["Season"].astype(str) + " " + soccer["Team"]

# %%
top10_us_c1 = us.nlargest(10, 'log_c1*')

plt.figure(figsize=(18,7))
sns.barplot(x='name', y='log_c1*', data=top10_us_c1, palette='tab10', hue='League')
plt.xlabel(None)
plt.ylabel('Logarithmic C1* Collapse Score', fontsize=16)
plt.title('Top 10 US Teams by log_c1*')
plt.legend(fontsize=14, title_fontsize=15)
plt.xticks(fontsize=14)
plt.xticks(rotation=45, fontsize=14, ha='right')
plt.savefig("figures/generalized_top10_us_c1.png", dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %%
top10_us_c2 = us.nlargest(10, 'log_c2*')

plt.figure(figsize=(18,7))
sns.barplot(x='name', y='log_c2*', data=top10_us_c2, palette='tab10', hue='League')
plt.xlabel(None)
plt.ylabel('Logarithmic C2* Collapse Score', fontsize=16)
plt.title('Top 10 US Teams by log_c2*')
plt.legend(fontsize=14, title_fontsize=15)
plt.xticks(fontsize=14)
plt.xticks(rotation=45, fontsize=14, ha='right')
plt.savefig("figures/generalized_top10_us_c2.png", dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %%
top10_soccer_c1 = soccer.nlargest(10, 'log_c1*')

plt.figure(figsize=(18,7))
sns.barplot(x='name', y='log_c1*', data=top10_soccer_c1, palette='tab10', hue='League')
plt.xlabel(None)
plt.ylabel('Logarithmic C1* Collapse Score', fontsize=16)
plt.title('Top 10 Soccer Teams by log_c1*')
plt.legend(fontsize=14, title_fontsize=15)
plt.xticks(fontsize=14)
plt.xticks(rotation=45, fontsize=14, ha='right')
plt.savefig("figures/generalized_top10_soccer_c1.png", dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %%
top10_soccer_c2 = soccer.nlargest(10, 'log_c2*')

plt.figure(figsize=(18,7))
sns.barplot(x='name', y='log_c2*', data=top10_soccer_c2, palette='tab10', hue='League')
plt.xlabel(None)
plt.ylabel('Logarithmic C2* Collapse Score', fontsize=16)
plt.title('Top 10 Soccer Teams by log_c2*')
plt.legend(fontsize=14, title_fontsize=15)
plt.xticks(fontsize=14)
plt.xticks(rotation=45, fontsize=14, ha='right')
plt.savefig("figures/generalized_top10_soccer_c2.png", dpi=300, bbox_inches='tight')
plt.show()
plt.close()
