# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
us = pd.read_csv("csvs/us_generalized_cscores.csv")
soccer = pd.read_csv("csvs/soccer_generalized_cscores.csv")

# %%
us['log_c1*'] = np.log(us['c1*'])
soccer['log_c1*'] = np.log(soccer['c1*'])

us['log_c2*'] = np.log(us['c2*'])
soccer['log_c2*'] = np.log(soccer['c2*'])
# Out:
# C:\Users\ryanj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\ryanj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
us["name"] = us["Season"].astype(str) + " " + us["Team"]
soccer["name"] = soccer["Season"].astype(str) + " " + soccer["Team"]

# %%
top10_us_c1 = us.nlargest(10, 'log_c1*')

plt.figure(figsize=(10,6))
sns.barplot(x='name', y='log_c1*', data=top10_us_c1, palette='Blues_d')
plt.xlabel('Team')
plt.ylabel('log_c1*')
plt.title('Top 10 US Teams by log_c1*')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
plt.close()
# Out:
# C:\Users\ryanj\AppData\Local\Temp\ipykernel_144388\3842628828.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='name', y='log_c1*', data=top10_us_c1, palette='Blues_d')

# %%
top10_us_c2 = us.nlargest(10, 'log_c2*')

plt.figure(figsize=(10,6))
sns.barplot(x='name', y='log_c2*', data=top10_us_c2, palette='Blues_d')
plt.xlabel('Team')
plt.ylabel('log_c2*')
plt.title('Top 10 US Teams by log_c2*')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
plt.close()
# Out:
# C:\Users\ryanj\AppData\Local\Temp\ipykernel_144388\2775163928.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='name', y='log_c2*', data=top10_us_c2, palette='Blues_d')

# %%
top10_soccer_c1 = soccer.nlargest(10, 'log_c1*')

plt.figure(figsize=(10,6))
sns.barplot(x='name', y='log_c1*', data=top10_soccer_c1, palette='Blues_d')
plt.xlabel('Team')
plt.ylabel('log_c1*')
plt.title('Top 10 Soccer Teams by log_c1*')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
plt.close()
# Out:
# C:\Users\ryanj\AppData\Local\Temp\ipykernel_144388\4293518159.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='name', y='log_c1*', data=top10_soccer_c1, palette='Blues_d')

# %%
top10_soccer_c2 = soccer.nlargest(10, 'log_c2*')

plt.figure(figsize=(10,6))
sns.barplot(x='name', y='log_c2*', data=top10_soccer_c2, palette='Blues_d')
plt.xlabel('Team')
plt.ylabel('log_c2*')
plt.title('Top 10 Soccer Teams by log_c2*')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
plt.close()
# Out:
# C:\Users\ryanj\AppData\Local\Temp\ipykernel_144388\4023740849.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='name', y='log_c2*', data=top10_soccer_c2, palette='Blues_d')
