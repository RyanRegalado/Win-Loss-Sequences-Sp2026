# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math

# %%
soccer_ternary_scores = pd.read_csv('../output/csvs/soccer_ternary_output.csv')
soccer_ternary_scores
# Out:
#       Unnamed: 0      League  Season           Team  \
# 0              0  Bundesliga    2000  Bayern Munich
# 1              1  Bundesliga    2000         Bochum
# 2              2  Bundesliga    2000        Cottbus
# 3              3  Bundesliga    2000       Dortmund
# 4              4  Bundesliga    2000  Ein Frankfurt
# ...          ...         ...     ...            ...
# 1433        1433     La_Liga    2024       Sociedad
# 1434        1434     La_Liga    2024       Valencia
# 1435        1435     La_Liga    2024     Valladolid
# 1436        1436     La_Liga    2024      Vallecano
# 1437        1437     La_Liga    2024     Villarreal
#
#                                                Sequence   n  n1  n2   k  k1  \
# 0     [3, 3, 3, 0, 3, 3, 0, 0, 3, 1, 3, 0, 0, 1, 3, ...  34  17  17  63  30
# 1     [3, 0, 0, 0, 3, 1, 3, 0, 0, 0, 1, 0, 1, 0, 3, ...  34  17  17  27  18
# 2     [0, 0, 0, 3, 0, 0, 1, 3, 0, 3, 1, 3, 0, 0, 3, ...  34  17  17  39  17
# 3     [3, 3, 0, 3, 3, 0, 1, 3, 0, 0, 0, 3, 1, 3, 3, ...  34  17  17  58  30
# 4     [3, 0, 3, 0, 3, 1, 1, 0, 0, 3, 0, 3, 3, 0, 0, ...  34  17  17  35  20
# ...                                                 ...  ..  ..  ..  ..  ..
# 1433  [0, 3, 0, 1, 0, 0, 1, 3, 1, 3, 0, 3, 3, 0, 3, ...  38  19  19  46  28
# 1434  [0, 0, 0, 1, 0, 3, 1, 0, 1, 0, 1, 3, 0, 0, 0, ...  38  19  19  46  13
# 1435  [3, 0, 1, 0, 0, 1, 0, 0, 0, 3, 0, 0, 1, 0, 0, ...  38  19  19  16  15
# 1436  [3, 1, 0, 0, 3, 1, 1, 1, 3, 0, 3, 0, 0, 0, 3, ...  38  19  19  52  25
# 1437  [1, 3, 3, 1, 3, 0, 3, 3, 0, 1, 3, 3, 1, 1, 0, ...  38  19  19  70  30
#
#       k2           Team_Name            c2         c3
# 0     33  2000 Bayern Munich      1.370834   1.418440
# 1      9         2000 Bochum     46.089683   6.896552
# 2     22        2000 Cottbus      1.182258   1.342282
# 3     28       2000 Dortmund      2.901612   2.314815
# 4     15  2000 Ein Frankfurt      6.733019   3.333333
# ...   ..                 ...           ...        ...
# 1433  18       2024 Sociedad     35.552617   6.896552
# 1434  33       2024 Valencia      1.000067   1.001001
# 1435   1     2024 Valladolid  12495.251146  90.661831
# 1436  27      2024 Vallecano      1.546616   1.589825
# 1437  40     2024 Villarreal      1.027945   1.072961
#
# [1438 rows x 14 columns]

# %% [markdown]
# ## Most Extreme Collapses

# %% [markdown]
# ### C2 Metric

# %%
soccer_ternary_scores['log_c2'] = np.log(soccer_ternary_scores['c2'])
top20_c2 = soccer_ternary_scores.nlargest(20, "log_c2")[["Season", "League", "Team_Name", "log_c2"]]

# %%
plt.figure(figsize=(18,7))

sns.barplot(x=top20_c2['Team_Name'], y = top20_c2['log_c2'], palette = 'tab10', hue = top20_c2['League'])
plt.title('Top 20 most extreme collapses across Premier League, Bundesliga, and La Liga (C2 Score)')
plt.xlabel('Season/Team')
plt.ylabel('Logarithmic C2 Collapse Score ')
plt.xticks(rotation=45, fontsize=11, ha='right') 
plt.show()

# %% [markdown]
# ### C3 metric

# %%
soccer_ternary_scores['log_c3'] = np.log(soccer_ternary_scores['c3'])
top20_c3 = soccer_ternary_scores.nlargest(20, "log_c3")[["Season", "League", "Team_Name", "log_c3"]]

# %%
plt.figure(figsize=(18,7))

sns.barplot(x=top20_c3['Team_Name'], y = top20_c3['log_c3'], palette = 'tab10', hue = top20_c3['League'])
plt.title('Top 20 most extreme collapses across Premier League, Bundesliga, and La Liga (C3 Score)')
plt.xlabel('Season/Team')
plt.ylabel('Logarithmic C3 Collapse Score ')
plt.xticks(rotation=45, fontsize=11, ha='right') 
plt.show()
